# %% [markdown]
# # Week 2 Sketchbook
#
# This week's sketchbook is also an exercise in creating your own notebook markdown and code cells. Look at the [class notebook](./week2_python_essentials.ipynb), read through it and stop at where you see:
#
# ### ⛩ Prompt
#
# Then create a Markdown section with a title (+ Markdown), followed by one or more Python code cells (+ Code), where you will copy code from before the prompt and modify it for you experiments. Make sure you select the py5 environment from the top of your window for cells to run. You will see something like:
#
# ![image.png](attachment:image.png)
#
# And make sure you import `py5canvas`, which is done below:)

# %%
from py5canvas import *

# %% [markdown]
# ## This is an example of a title you could create
# With some text?
