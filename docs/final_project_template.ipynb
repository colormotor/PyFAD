# %% [markdown]
# ### Your Name – Title of Work

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Introduction
#
# Write a short introduction, a short paragraph, giving a bit more detail about what the project is.

# %% [markdown]
# ## Concept and Background Research
#
# Write about the concept behind the project, in other words the creative or theoretical inspiration. Include details about any background research you may have done (don’t forget to include references in the reference section and cite those here). Consider writing about your work in relation to a creative, theoretical or computational tradition that you may be taking inspiration from, in other words think about how your work is situated in a particular making tradition.
#
# >Include any concept sketches here if you have any. Keep in mind that it is easy to paste images into a notebook, but you will lose the images if you copy the text of a markdown cell to another, or if you split the cell.

# %% [markdown]
# ## Technical Implementation
#
# Write about the process of implementing your project. What technical elements or hardware are involved in your system. Write about why you made certain technical or design decisions etc.
#
# - Include images to illustrate your process
# - You can write "inline" python in a markdown cell by using the surrounding text with a pair of \`\`. E.g. `sin(t)`.
# - Don't add images of code, if you want to describe some code that is not supposed to work in the notebook you can use this syntax (double click the cell to see the source):
# ```python
# some_example_code(1, 2, 3)
# ```

# %% [markdown]
# - Add the executable code for your work in code cells. Try to keep the code cells relatively short so the document remains readable. You can use define functions in separate code cells to make things more modular and concise.

# %% [markdown]
# As an example, you might define this function and describe it

# %%
def my_function(x, y, w):
    circle(x, y, w)

# %% [markdown]
# And then use it in a canvas:

# %%
from py5canvas import *

size(200, 200)
translate(center)
my_function(0, 0, 150)
show()
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %% [markdown]
# If you want to write math in a notebook you can use simple [LaTeX](https://www.latex-project.org), e.g to write the constant $\pi$.

# %% [markdown]
# ## Reflection and Future Development
#
# Reflect on how the project went, what went well, what you learnt etc. Based on these reflections, conclude with how you would further develop this project if you were to make another version or how you would further develop your ideas.

# %% [markdown]
# ## References
#
# Use the citation method that is standard in an academic field you are interested in. At the very least include both conceptual and technical references. If you have used anyone else’s code even if you have adapted it, you must cite it here or risk being penalized or disqualified for plagiarism!
#
# If you use AI for significant parts of your code, acknowledge where it was used here. If we strongly suspect you used AI and you do not acknowledge it and explain how it was used in the report, it may significantly lower your grade.
